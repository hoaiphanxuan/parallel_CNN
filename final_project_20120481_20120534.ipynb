# %%
# https://drive.google.com/file/d/1gyjBYxDuXxo96cZV2h-cPSlB7vxA40g_/view?usp=drive_link 20120481_20120534.zip

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/drive/MyDrive/20120481_20120534.zip /content/

# %%
# !unzip -q 20120481_20120534.zip

# %%
# %cd 20120481_20120534
# Out:
# /content/20120481_20120534

# %%
# !make compile
# Out:
# rm -f *.o src/*.o src/layer/*.o src/loss/*.o src/optimizer/*.o src/gpu_src/*.o
# make network.o
# make[1]: Entering directory '/content/20120481_20120534'
# nvcc --compile src/network.cc -o src/network.o -I./ -L/usr/local/cuda/lib64 -lcudart
# make[1]: Leaving directory '/content/20120481_20120534'
# make fashion_mnist.o
# make[1]: Entering directory '/content/20120481_20120534'
# nvcc --compile src/fashion_mnist.cc -o src/fashion_mnist.o  -I./ -L/usr/local/cuda/lib64 -lcudart
# make[1]: Leaving directory '/content/20120481_20120534'
# make layer.o
# make[1]: Entering directory '/content/20120481_20120534'
# nvcc --compile src/layer/ave_pooling.cc -o src/layer/ave_pooling.o -I./ -L/usr/local/cuda/lib64 -lcudart
# nvcc --compile src/layer/fully_connected.cc -o src/layer/fully_connected.o -I./ -L/usr/local/cuda/lib64 -lcudart
# nvcc --compile src/layer/max_pooling.cc -o src/layer/max_pooling.o -I./ -L/usr/local/cuda/lib64 -lcudart
# ...

# %%
# !make train_model

# %%
# !make -s host_convolution
# Out:
# number test samples: 10000
# host - Convolution C1: 35764.3 ms
# host - Convolution C3: 31789 ms
# accuracy: 0.8296

# %%
# !make -s kernel_convolution_basic
# Out:
# **********GPU info**********
# Name: Tesla T4
# Compute capability: 7.5
# Num SMs: 40
# Max num threads per SM: 1024
# Max num warps per SM: 32
# GMEM: 15835660288 byte
# SMEM per SM: 65536 byte
# SMEM per block: 49152 byte
# ****************************
# number test samples: 10000
# basic:
#   - Kernel time C1 : 122.58 ms
#   - Convolution C1: 125.528 ms
#
# basic:
#   - Kernel time C3 : 61.1396 ms
#   - Convolution C3: 65.5313 ms
#
# test accuracy: 0.8296

# %%
# !make -s kernel_convolution_optimize_0
# Out:
# **********GPU info**********
# Name: Tesla T4
# Compute capability: 7.5
# Num SMs: 40
# Max num threads per SM: 1024
# Max num warps per SM: 32
# GMEM: 15835660288 byte
# SMEM per SM: 65536 byte
# SMEM per block: 49152 byte
# ****************************
# number test samples: 10000
# optimize 0: Unrolling loop
#   - Kernel time C1 : 119.908 ms
#   - Convolution C1: 123.315 ms
#
# optimize 0: Unrolling loop
#   - Kernel time C3 : 51.5615 ms
#   - Convolution C3: 55.5977 ms
#
# test accuracy: 0.8296

# %%
# !make -s kernel_convolution_optimize_1
# Out:
# **********GPU info**********
# Name: Tesla T4
# Compute capability: 7.5
# Num SMs: 40
# Max num threads per SM: 1024
# Max num warps per SM: 32
# GMEM: 15835660288 byte
# SMEM per SM: 65536 byte
# SMEM per block: 49152 byte
# ****************************
# number test samples: 10000
# optimize 1: shared memory and constant memory
#   - Kernel time C1 : 120.955 ms
#   - Convolution C1: 124.2 ms
#
# optimize 1: shared memory and constant memory
#   - Kernel time C3 : 47.0913 ms
#   - Convolution C3: 50.4288 ms
#
# test accuracy: 0.8296

# %%
# !make -s kernel_convolution_optimize_2
# Out:
# **********GPU info**********
# Name: Tesla T4
# Compute capability: 7.5
# Num SMs: 40
# Max num threads per SM: 1024
# Max num warps per SM: 32
# GMEM: 15835660288 byte
# SMEM per SM: 65536 byte
# SMEM per block: 49152 byte
# ****************************
# number test samples: 10000
# optimize 2: stream
#   - Kernel time C1 : 13.2949 ms
#   - Convolution C1: 18.179 ms
#
# optimize 2: stream
#   - Kernel time C3 : 15.188 ms
#   - Convolution C3: 18.6921 ms
#
# test accuracy: 0.8296

# %%
# !make -s kernel_convolution_optimize_3
# Out:
# **********GPU info**********
# Name: Tesla T4
# Compute capability: 7.5
# Num SMs: 40
# Max num threads per SM: 1024
# Max num warps per SM: 32
# GMEM: 15835660288 byte
# SMEM per SM: 65536 byte
# SMEM per block: 49152 byte
# ****************************
# number test samples: 10000
# optimize 3: stream, shared memory, constant memory, and unrolling loop
#   - Kernel time C1 : 13.3483 ms
#   - Convolution C1: 16.6544 ms
#
# optimize 3: stream, shared memory, constant memory, and unrolling loop
#   - Kernel time C3 : 9.99354 ms
#   - Convolution C3: 13.2731 ms
#
# test accuracy: 0.8296
